# %% [markdown]
# # Using the MTCARS data set:
#
# - 1) Apply backward elimination to find top 3 input variables which impact the mileage of the car
#
# - 2) Apply factor analysis to see which columns can be grouped together

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_kmo

# %%
mtcars = pd.read_csv('F:\Skillenable\Data frames\mtcars.csv')
mtcars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars= mtcars.rename(columns={'Unnamed: 0':'Cars'})

# %%
#  backward elimination
# define X and Y

Y = cars[['mpg']]
X = cars.drop(columns='mpg')

# %%
# spliting data
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size = 0.8, random_state = 1234)

len(X_train), len(X_test), len(Y_train), len(Y_test)
# Out:
# (25, 7, 25, 7)

# %%
# the black linear Regration object
lm = LinearRegression()

# %%
# the set of effective input variable (Feature selection)

from mlxtend.feature_selection import SequentialFeatureSelector as sfs
column_name = sfs(lm, k_features= 3, forward=False, verbose= 1)

# %%
# name of top 3 input column
final_sfs = column_name.fit(X,Y)
list(final_sfs.k_feature_names_)
# Out:
# C:\Users\arun\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\arun\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\arun\anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 662, in fit
#     X, y = self._validate_data(
#   File "C:\Users\arun\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
# ...

# %% [markdown]
# ## 'Cars', 'cyl', 'disp' are top 3 input variable.

# %% [markdown]
# # Factor analyser

# %%
# drop na columns
cars_fa = cars.drop(columns='Cars')
cars_fa.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
# KMO test
kmo_all, kmo_model = calculate_kmo(cars_fa)
print(kmo_model)
# Out:
# 0.8172608566882739

# %%
# creating 10 factors  to find the right number of factors inwhich this data can be divided

# Creating a factor object
fa = FactorAnalyzer(n_factors = 10, rotation = None)

# %%
# Fit the object on data frame
fa.fit(cars_fa)
# Out:
# FactorAnalyzer(n_factors=10, rotation=None, rotation_kwargs={})

# %%
#eigen value
eigen_values, eigen_values = fa.get_eigenvalues()
list(eigen_values)
# Out:
# [6.541060583085067,
#  2.5552843998084653,
#  0.5564661443227459,
#  0.17890599736279694,
#  0.15366051089188462,
#  0.05307692051826653,
#  0.046971378800303706,
#  0.0313562198107952,
#  0.012754432425049044,
#  0.003495427788041288,
#  -1.6681936918220112e-05]

# %%
# creating model for n_factor = 2
fa_final = FactorAnalyzer(n_factors=2, rotation = 'varimax')

# %%
fa_final.fit(cars_fa)
# Out:
# FactorAnalyzer(n_factors=2, rotation='varimax', rotation_kwargs={})

# %%
# printing loading factor
fa_final.loadings_
# Out:
# array([[ 0.67513349, -0.63009292],
#        [-0.63413563,  0.73050763],
#        [-0.72736215,  0.60737452],
#        [-0.31647142,  0.88107685],
#        [ 0.8124605 , -0.21895483],
#        [-0.78392609,  0.45401531],
#        [-0.15050928, -0.87250904],
#        [ 0.2954181 , -0.78761255],
#        [ 0.90113376,  0.0668503 ],
#        [ 0.88180246,  0.15015455],
#        [ 0.05485586,  0.80925134]])

# %%
#have a dataframe
loading_df = pd.DataFrame(fa_final.loadings_, columns=['Factor1', 'Factor2'], index = cars_fa.columns)
loading_df
# Out:
#        Factor1   Factor2
# mpg   0.675133 -0.630093
# cyl  -0.634136  0.730508
# disp -0.727362  0.607375
# hp   -0.316471  0.881077
# drat  0.812460 -0.218955
# wt   -0.783926  0.454015
# qsec -0.150509 -0.872509
# vs    0.295418 -0.787613
# am    0.901134  0.066850
# gear  0.881802  0.150155
# carb  0.054856  0.809251
